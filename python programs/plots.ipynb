# %%
import random
import numpy as np
import matplotlib.pyplot as plt
class Plot:
    def plot_1():
        x_axis=np.random.randint(10,90,8)
        y_axis=np.random.randint(10,90,8)
        print("x-axis : ",x_axis)
        print("y-axis : ",y_axis)
        plt.plot(x_axis,marker="o",mfc="blue",color="magenta")
        plt.plot(y_axis,marker="o",mfc="red",color="indigo")
        plt.grid(color="green")
        plt.xlabel("students")
        plt.ylabel("placement")
        plt.title("SIT")
        plt.show()
Plot.plot_1()
# Out:
# x-axis :  [19 67 80 54 55 73 83 13]
# y-axis :  [59 40 49 61 23 41 36 51]
